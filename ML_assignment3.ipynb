# %% [markdown]
# <a href="https://colab.research.google.com/github/yaya1721/ML-spring22/blob/main/ML_assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Machine Learning Assignment 3
# Dania Herzalla dh2741 <br>
# Long Phan lvp243 <br>
# Sonya Hsieh yh3529 <br>

# %% [markdown]
# ## Problem 1

# %% [markdown]
# Completed

# %% [markdown]
# ## Problem 2

# %% [markdown]
# part 1

# %% [markdown]
# ![prob1iteration1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# part 2

# %% [markdown]
# ![275048379_2761387094169954_2783645288933367513_n.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Problem 3

# %% [markdown]
# The loss ln (1 + e^(y*h(x)) follows the logitboost algorithm
# We redefine the weight vector and the classification fo the logitboost classifer sign(F(x))

# %% [markdown]
# ![prob3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Problem 4

# %% [markdown]
# https://github.com/yaya1721/viola-jones

# %%
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier
import cv2 as cv
import numpy as np
import pandas as pd 
import os
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7ecf0b11-0d4d-4ad1-927f-09ec3ff09270" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7ecf0b11-0d4d-4ad1-927f-09ec3ff09270">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving face.train.tar.gz to face.train.tar.gz

# %%
print(os.getcwd())
# Out:
# /content

# %%
import tarfile
import numpy as np 

tar = tarfile.open("face.train.tar.gz", "r:gz")
for member in tar.getmembers():
     f = tar.extractfile(member)
     img = cv.imread('/content/face.train.tar.gz/member')
     X.append(img)

# %%
# Create adaboost classifer object
abc = AdaBoostClassifier(n_estimators = 10, algorithm = {'SAMME'})

# %%
from sklearn import tree
for i in range(len(abc.estimators_)):
  print(f"Tree {i}: ")
  print(f"Weight: {abc.estimator_weights_[i]}")
  print(tree.export_text(abc.estimators_[i]))

# %% [markdown]
# ## Problem 5

# %% [markdown]
# ![prob5.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Text written in problem 5:
# We classify one input vector x by determining the sign of (vector a dot product vector x + b) which is equivalent to determining the sign of sum from 1 to k of (alpha_i * (vector x_i * vector x) + b)

# %% [markdown]
# Expression using Kernel function K(. , .):

# %% [markdown]
# ![prob5kernel.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Problem 6

# %% [markdown]
# Completed
